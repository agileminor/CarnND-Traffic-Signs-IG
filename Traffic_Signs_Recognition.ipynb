# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
# ## Project: Build a Traffic Sign Recognition Classifier
#
# In this notebook, a template is provided for you to implement your functionality in stages which is required to successfully complete this project. If additional code is required that cannot be included in the notebook, be sure that the Python code is successfully imported and included in your submission, if necessary. Sections that begin with **'Implementation'** in the header indicate where you should begin your implementation for your project. Note that some sections of implementation are optional, and will be marked with **'Optional'** in the header.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
# Load pickled data
import pickle
from sklearn.preprocessing import LabelBinarizer
from sklearn.cross_validation import train_test_split
from sklearn.utils import shuffle
from tqdm import tqdm
import os

training_file = r'../data/traffic-signs-data/train.p'
testing_file = r'../data/traffic-signs-data/test.p'

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 2D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**
#
# Complete the basic data summary below.

# %%
### Replace each question mark with the appropriate value.


n_train = X_train.shape[0]


n_test = X_test.shape[0]


image_shape = X_train[0].shape


n_classes = len(set(y_train))

print("Number of training examples =", n_train)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
#print(X_train)
# Out:
# Number of training examples = 39209
# Number of testing examples = 12630
# Image data shape = (32, 32, 3)
# Number of classes = 43

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections.

# %%
### Data exploration visualization goes here.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt
# Visualizations will be shown in the notebook.
# %matplotlib inline
plt.imshow(X_test[2])

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
# Design and implement a deep learning model that learns to recognize traffic signs. Train and test your model on the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset).
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.
#
# **NOTE:** The LeNet-5 implementation shown in the [classroom](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) at the end of the CNN lesson is a solid starting point. You'll have to change the number of classes and possibly the preprocessing, but aside from that it's plug and play!

# %% [markdown]
# ### Implementation
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project. Once you have completed your implementation and are satisfied with the results, be sure to thoroughly answer the questions that follow.

# %%
### Preprocess the data here.
### Feel free to use as many code cells as needed.

# normalize the images
import numpy as np
import cv2
# convert to greyscale
def grayscale(img):
    return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
def normalize(image_data):
    a = 0.01
    b = 0.99
    color_min = 0.0
    color_max = 255.0

    return a + ( ( (image_data - color_min) * (b - a) )/(color_max - color_min))


new_X_train = normalize(X_train)
new_X_test = normalize(X_test)

# add one hot encoding to labels
encoder = LabelBinarizer()
encoder.fit(y_train)
new_y_train = encoder.transform(y_train)
new_y_test = encoder.transform(y_test)
new_y_train = new_y_train.astype(np.float32)
new_y_test = new_y_test.astype(np.float32)

# flatten images
new_X_train = new_X_train.reshape((-1, 3072))
new_X_test = new_X_test.reshape((-1, 3072))

# %% [markdown]
# ### Question 1
#
# _Describe how you preprocessed the data. Why did you choose that technique?_

# %% [markdown]
# **Answer:**

# %%
### Generate data additional data (OPTIONAL!)
### and split the data into training/validation/testing sets here.
### Feel free to use as many code cells as needed.

# %%
# split training data into training/validation, 80% training, 20% validation

new_X_train, X_validation, new_y_train, y_validation = train_test_split(
    new_X_train,
    new_y_train,
    test_size=0.20,
    random_state=194234)
new_X_train, new_y_train = shuffle(new_X_train, new_y_train)
X_validation, y_validation = shuffle(X_validation, y_validation)

# %% [markdown]
# ### Question 2
#
# _Describe how you set up the training, validation and testing data for your model. **Optional**: If you generated additional data, how did you generate the data? Why did you generate the data? What are the differences in the new dataset (with generated data) from the original dataset?_

# %% [markdown]
# **Answer:**

# %%
### Define your architecture here.
### Feel free to use as many code cells as needed.
import tensorflow as tf
from tensorflow.contrib.layers import flatten
def conv2d(x, W, b, strides=1, pad_type='SAME'):
    # Conv2D wrapper, with bias and relu activation
    #F_W = tf.Variable(tf.truncated_normal(W, mean=0, stddev=0.01)) # (height, width, input_depth, output_depth)
    F_W = tf.Variable(tf.truncated_normal(W, stddev=0.1)) # (height, width, input_depth, output_depth)
    F_b = tf.Variable(tf.zeros(b)) # (output_depth)
    x = tf.nn.conv2d(x, F_W, strides=[1, strides, strides, 1], padding=pad_type)
    x = tf.nn.bias_add(x, F_b)
    return tf.nn.relu(x)

def maxpool(input, ksizes=2, stride=2, pad_type='VALID'):
    ksize = [1, ksizes, ksizes, 1]
    strides = [1, stride, stride, 1]
    return tf.nn.max_pool(input, ksize, strides, pad_type)

def fully_connected(input, output_size, biases):
    dim1 = input.get_shape().as_list()[-1]
    weights = tf.Variable(
    #tf.truncated_normal([dim1, output_size], mean=0, stddev=0.01))
    tf.truncated_normal([dim1, output_size], stddev=0.1))
    biases = tf.Variable(tf.zeros(biases))
    #return tf.nn.relu(tf.matmul(input, weights) + biases)
    return tf.matmul(input, weights) + biases
# LeNet architecture:
# INPUT -> CONV -> ACT -> POOL -> CONV -> ACT -> POOL -> FLATTEN -> FC -> ACT -> FC
#
def LeNet(x, keep_prob):
    # Reshape from 2D to 4D. This prepares the data for
    # convolutional and pooling layers.
    x = tf.reshape(x, (-1, 32, 32, 3))
    strides = {'conv1': 1, 'pool1': 2, 'conv2': 1, 'pool2': 2}
    # for conv layers, format is (filter_height, filter_width, input_depth, output_depth
    # for fully connected layers, format is output size
    weights = {'conv1': (5, 5, 3, 6), 'conv2': (5, 5, 6, 16), 'full1': 120, 'full2': 43}
    biases = {'conv1': 6, 'conv2': 16, 'full1': 120, 'full2': 43}
    paddings = {'conv1': 'VALID', 'pool1': 'VALID', 'conv2': 'VALID', 'pool2': 'VALID'}
    pool_filters = {'pool1': 2, 'pool2': 2}

    conv1_out = conv2d(x, weights['conv1'], biases['conv1'], strides=strides['conv1'], pad_type=paddings['conv1'])
    conv1_out = tf.nn.dropout(conv1_out, keep_prob)
    pool1_out = maxpool(conv1_out, ksizes=pool_filters['pool1'], stride=strides['pool1'], pad_type=paddings['pool1'])
    conv2_out = conv2d(pool1_out, weights['conv2'], biases['conv2'], strides=strides['conv2'], pad_type=paddings['conv2'])
    conv2_out = tf.nn.dropout(conv2_out, keep_prob)
    pool2_out = maxpool(conv2_out, ksizes=pool_filters['pool2'], stride=strides['pool2'], pad_type=paddings['pool2'])
    flat_out = flatten(pool2_out)
    full1_out = fully_connected(flat_out, weights['full1'],  biases['full1'])
    #full1_out = -np.amax(full1_out)
    full1_out = tf.nn.relu(full1_out)
    
    #full1_out = tf.nn.dropout(full1_out, keep_prob)

    full2_out = fully_connected(full1_out, weights['full2'],  biases['full2'])
    full2_out = -np.amax(full2_out)
    return full2_out

# %% [markdown]
# ### Question 3
#
# _What does your final architecture look like? (Type of model, layers, sizes, connectivity, etc.)  For reference on how to build a deep neural network using TensorFlow, see [Deep Neural Network in TensorFlow
# ](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/b516a270-8600-4f93-a0a3-20dfeabe5da6/concepts/83a3a2a2-a9bd-4b7b-95b0-eb924ab14432) from the classroom._

# %% [markdown]
# **Answer:**
# Input images are 32x32x3.
#
# Basic LeNet with 2 layers of convolution (5x5x6 and 5x5x16, relu activation) with 2x2 pooling after each layer, following by a 120 node  fully connected + relu activation layer and a 43 node fully connected layer, with drop out after each convolution layer.

# %%
### Train your model here.
### Feel free to use as many code cells as needed.

EPOCHS = 20
BATCH_SIZE = 50

x = tf.placeholder(tf.float32, (None, image_shape[0] * image_shape[1] * image_shape[2]))
y = tf.placeholder(tf.float32, (None, n_classes))
keep_prob = tf.placeholder(tf.float32)
fc2 = LeNet(x, keep_prob)


#loss_op = tf.reduce_mean(-tf.reduce_sum(y * tf.log(tf.clip_by_value(tf.nn.softmax(fc2),1e-10,1.0))))
#learning_rate = 0.001
#opt = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=fc2, labels=y))
opt = tf.train.AdamOptimizer()
train_op = opt.minimize(loss_op)
correct_prediction = tf.equal(tf.argmax(fc2, 1), tf.argmax(y, 1))
accuracy_op = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

saver = tf.train.Saver()

def next_batch(batch_size, features, labels):
    start = 0
    last = 0
    while last < len(features):
        start = last
        last = start + batch_size
        yield features[start:last], labels[start:last]

def batches(batch_size, features, labels):

    outout_batches = []
    
    sample_size = len(features)
    for start_i in range(0, sample_size, batch_size):
        end_i = start_i + batch_size
        batch = [features[start_i:end_i], labels[start_i:end_i]]
        outout_batches.append(batch)
        
    return outout_batches
def eval_data(features, labels):
    """
    Given a dataset as input returns the loss and accuracy.
    """

    steps_per_epoch = len(features) // BATCH_SIZE
    num_examples = steps_per_epoch * BATCH_SIZE
    total_acc, total_loss = 0, 0
    batches = next_batch(BATCH_SIZE, features, labels)
    #val_batches = batches(BATCH_SIZE, features, labels)
    #for batch_x, batch_y in val_batches:
    #    loss, acc = sess.run([loss_op, accuracy_op], feed_dict={x: batch_x, y: batch_y, keep_prob: 1.0})
    #    total_acc += (acc * len(batch_x))
    #    total_loss += (loss * len(batch_x))    
    for step in range(steps_per_epoch):
        batch_x, batch_y = next(batches)
        loss, acc = sess.run([loss_op, accuracy_op], feed_dict={x: batch_x, y: batch_y, keep_prob: 1.0})
        total_acc += (acc * len(batch_x))
        total_loss += (loss * len(batch_x))
    return total_loss/num_examples, total_acc/num_examples


with tf.Session() as sess:
    sess.run(tf.initialize_all_variables())
    steps_per_epoch = len(new_X_train) // BATCH_SIZE
    num_examples = steps_per_epoch * BATCH_SIZE
    # Train model
    
    print("starting")
    for i in range(EPOCHS):
        new_X_train, new_y_train = shuffle(new_X_train, new_y_train)
        batches = next_batch(BATCH_SIZE, new_X_train, new_y_train)
        batches_pbar = tqdm(range(steps_per_epoch), desc='Epoch {:>2}/{}'.format(i+1, EPOCHS), unit='batches')
        for step in batches_pbar:
            batch_x, batch_y = next(batches)
            loss = sess.run(train_op, feed_dict={x: batch_x, y: batch_y, keep_prob: 0.5})

        val_loss, val_acc = eval_data(X_validation, y_validation)
        print("EPOCH {} ...".format(i+1))
        print("Validation loss = {:.3f}".format(val_loss))
        print("Validation accuracy = {:.3f}".format(val_acc))
        print()

    # Evaluate on the test data
    test_loss, test_acc = eval_data(new_X_test, new_y_test)
    print("Test loss = {:.3f}".format(test_loss))
    print("Test accuracy = {:.3f}".format(test_acc))
    save_path = saver.save(sess, "./model.ckpt")
    print("Model saved in file: %s" % save_path)
    #print out predictions, use .index(1.0) on one_hot
    #for ind, img in enumerate(new_X_test):
    #    result = sess.run(fc2, feed_dict={x: [img]})
    #    print (list(result[0]).index(max(result[0])), list(new_y_test[ind]).index(1))
# Out:
# starting
# Epoch  1/20: 100%|██████████| 627/627 [00:35<00:00, 19.78batches/s]
# EPOCH 1 ...
# Validation loss = 1.136
# Validation accuracy = 0.800
# Epoch  2/20: 100%|██████████| 627/627 [00:33<00:00, 18.57batches/s]
# EPOCH 2 ...
# Validation loss = 0.652
# Validation accuracy = 0.901
# Epoch  3/20: 100%|██████████| 627/627 [00:32<00:00, 20.53batches/s]
# EPOCH 3 ...
# Validation loss = 0.480
# Validation accuracy = 0.925
# Epoch  4/20: 100%|██████████| 627/627 [00:30<00:00, 20.60batches/s]
# EPOCH 4 ...
# Validation loss = 0.370
# Validation accuracy = 0.948
# Epoch  5/20: 100%|██████████| 627/627 [00:30<00:00, 20.19batches/s]
# EPOCH 5 ...
# Validation loss = 0.319
# Validation accuracy = 0.956
# Epoch  6/20: 100%|██████████| 627/627 [00:30<00:00, 20.57batches/s]
# EPOCH 6 ...
# Validation loss = 0.288
# Validation accuracy = 0.966
# Epoch  7/20: 100%|██████████| 627/627 [00:30<00:00, 21.06batches/s]
# EPOCH 7 ...
# Validation loss = 0.249
# Validation accuracy = 0.968
# Epoch  8/20: 100%|██████████| 627/627 [00:30<00:00, 19.60batches/s]
# EPOCH 8 ...
# Validation loss = 0.201
# Validation accuracy = 0.971
# Epoch  9/20: 100%|██████████| 627/627 [00:38<00:00, 17.03batches/s]
# EPOCH 9 ...
# Validation loss = 0.188
# Validation accuracy = 0.966
# Epoch 10/20: 100%|██████████| 627/627 [00:39<00:00, 15.69batches/s]
# EPOCH 10 ...
# Validation loss = 0.164
# Validation accuracy = 0.977
# Epoch 11/20: 100%|██████████| 627/627 [00:39<00:00, 17.61batches/s]
# EPOCH 11 ...
# Validation loss = 0.172
# Validation accuracy = 0.972
# Epoch 12/20: 100%|██████████| 627/627 [00:35<00:00, 17.87batches/s]
# EPOCH 12 ...
# Validation loss = 0.152
# Validation accuracy = 0.976
# Epoch 13/20: 100%|██████████| 627/627 [00:40<00:00, 17.48batches/s]
# EPOCH 13 ...
# Validation loss = 0.128
# Validation accuracy = 0.984
# Epoch 14/20: 100%|██████████| 627/627 [00:40<00:00, 10.40batches/s]
# EPOCH 14 ...
# Validation loss = 0.135
# Validation accuracy = 0.979
# Epoch 15/20: 100%|██████████| 627/627 [00:36<00:00, 19.40batches/s]
# EPOCH 15 ...
# Validation loss = 0.132
# Validation accuracy = 0.977
# Epoch 16/20: 100%|██████████| 627/627 [00:32<00:00, 19.47batches/s]
# EPOCH 16 ...
# Validation loss = 0.123
# Validation accuracy = 0.981
# Epoch 17/20: 100%|██████████| 627/627 [00:32<00:00, 18.69batches/s]
# EPOCH 17 ...
# Validation loss = 0.120
# Validation accuracy = 0.978
# Epoch 18/20: 100%|██████████| 627/627 [00:37<00:00, 16.77batches/s]
# EPOCH 18 ...
# Validation loss = 0.102
# Validation accuracy = 0.982
# Epoch 19/20: 100%|██████████| 627/627 [00:36<00:00, 17.36batches/s]
# EPOCH 19 ...
# Validation loss = 0.102
# Validation accuracy = 0.982
# Epoch 20/20: 100%|██████████| 627/627 [00:37<00:00, 19.42batches/s]
# EPOCH 20 ...
# Validation loss = 0.095
# Validation accuracy = 0.985
#
# Test loss = 0.278
# Test accuracy = 0.930
# Model saved in file: ./model.ckpt

# %% [markdown]
# ### Question 4
#
# _How did you train your model? (Type of optimizer, batch size, epochs, hyperparameters, etc.)_

# %% [markdown]
# **Answer:**
# Optimizer = AdamOptimizer with default learning rate of 0.001
# Epochs = 10
# Batch size = 50
# drop out probability during training = 50%

# %% [markdown]
# ### Question 5
#
#
# _What approach did you take in coming up with a solution to this problem? It may have been a process of trial and error, in which case, outline the steps you took to get to the final solution and why you chose those steps. Perhaps your solution involved an already well known implementation or architecture. In this case, discuss why you think this is suitable for the current problem._

# %% [markdown]
# **Answer:**
#
# I wanted to use the full colour images, rather than grayscale, so I had to adapt the LeNet code to use 3 colour images, and apply normalization.
#
# Initial results were very bad. This had to do with issues with the splitting of the data into validation/training. Once I switched to using the sklearn train_test_split function, results improved. Only change after that was to add drop to avoid overfitting.
# After trial and error, 10 epochs with batch size of 50 produced decent results. Also tried a gradient descent optimizer, with similar results

# %% [markdown]
# ---
#
# ## Step 3: Test a Model on New Images
#
# Take several pictures of traffic signs that you find on the web or around you (at least five), and run them through your classifier on your computer to produce example results. The classifier might not recognize some local signs but it could prove interesting nonetheless.
#
# You may find `signnames.csv` useful as it contains mappings from the class id (integer) to the actual sign name.

# %% [markdown]
# ### Implementation
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project. Once you have completed your implementation and are satisfied with the results, be sure to thoroughly answer the questions that follow.

# %%
### Load the images and plot them here.
### Feel free to use as many code cells as needed.

img_folder = r'../data/new_signs'
files = os.listdir(img_folder)
new_images = []
for fname in files:
    if fname[0] != ".":
        print (fname)
        img = cv2.imread(img_folder + '/' + fname)
        img = cv2.resize(img, (32, 32))
        print(img.shape)
        new_images.append(img)
        plt.imshow(img)
        plt.show()
new_images = np.array(new_images)
new_images = normalize(new_images)


# flatten images
new_images = new_images.reshape((-1, 3072))
# Out:
# block.jpeg
# (32, 32, 3)
# no_entry.jpeg
# (32, 32, 3)
# stop.JPG
# (32, 32, 3)
# twist.jpeg
# (32, 32, 3)
# yield.JPG
# (32, 32, 3)

# %% [markdown]
# ### Question 6
#
# _Choose five candidate images of traffic signs and provide them in the report. Are there any particular qualities of the image(s) that might make classification difficult? It could be helpful to plot the images in the notebook._

# %% [markdown]
# **Answer:**

# %%
### Run the predictions here.
### Feel free to use as many code cells as needed.
with tf.Session() as sess:
  # Restore variables from disk.
  saver.restore(sess, "./model.ckpt")
  print("Model restored.")
  results = sess.run(fc2, feed_dict={x: new_images, keep_prob: 1.0})
  # Do some work with the model
  for item in results:
        print (list(item).index(max(item)))
# Out:
# Model restored.
# 11
# 34
# 33
# 23
# 13

# %% [markdown]
# ### Question 7
#
# _Is your model able to perform equally well on captured pictures when compared to testing on the dataset? The simplest way to do this check the accuracy of the predictions. For example, if the model predicted 1 out of 5 signs correctly, it's 20% accurate._
#
# _**NOTE:** You could check the accuracy manually by using `signnames.csv` (same directory). This file has a mapping from the class id (0-42) to the corresponding sign name. So, you could take the class id the model outputs, lookup the name in `signnames.csv` and see if it matches the sign from the image._

# %% [markdown]
# **Answer:**
# Results were not as good on captured images - 40% (2/5 correct)

# %%
### Visualize the softmax probabilities here.
### Feel free to use as many code cells as needed.
with tf.Session() as sess:
    sess.run(tf.nn.top_k(tf.constant(results), k=3))

# %% [markdown]
# ### Question 8
#
# *Use the model's softmax probabilities to visualize the **certainty** of its predictions, [`tf.nn.top_k`](https://www.tensorflow.org/versions/r0.12/api_docs/python/nn.html#top_k) could prove helpful here. Which predictions is the model certain of? Uncertain? If the model was incorrect in its initial prediction, does the correct prediction appear in the top k? (k should be 5 at most)*
#
# `tf.nn.top_k` will return the values and indices (class ids) of the top k predictions. So if k=3, for each sign, it'll return the 3 largest probabilities (out of a possible 43) and the correspoding class ids.
#
# Take this numpy array as an example:
#
# ```
# # (5, 6) array
# a = np.array([[ 0.24879643,  0.07032244,  0.12641572,  0.34763842,  0.07893497,
#          0.12789202],
#        [ 0.28086119,  0.27569815,  0.08594638,  0.0178669 ,  0.18063401,
#          0.15899337],
#        [ 0.26076848,  0.23664738,  0.08020603,  0.07001922,  0.1134371 ,
#          0.23892179],
#        [ 0.11943333,  0.29198961,  0.02605103,  0.26234032,  0.1351348 ,
#          0.16505091],
#        [ 0.09561176,  0.34396535,  0.0643941 ,  0.16240774,  0.24206137,
#          0.09155967]])
# ```
#
# Running it through `sess.run(tf.nn.top_k(tf.constant(a), k=3))` produces:
#
# ```
# TopKV2(values=array([[ 0.34763842,  0.24879643,  0.12789202],
#        [ 0.28086119,  0.27569815,  0.18063401],
#        [ 0.26076848,  0.23892179,  0.23664738],
#        [ 0.29198961,  0.26234032,  0.16505091],
#        [ 0.34396535,  0.24206137,  0.16240774]]), indices=array([[3, 0, 5],
#        [0, 1, 4],
#        [0, 5, 1],
#        [1, 3, 5],
#        [1, 4, 3]], dtype=int32))
# ```
#
# Looking just at the first row we get `[ 0.34763842,  0.24879643,  0.12789202]`, you can confirm these are the 3 largest probabilities in `a`. You'll also notice `[3, 0, 5]` are the corresponding indices.

# %% [markdown]
# **Answer:**

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
